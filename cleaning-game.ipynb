# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import plotly.express as px
import os
import sqlite3

# %%
df=pd.read_csv('olympic_dataset.csv', encoding='utf-8')
df.shape
# Out:
# (145500, 16)

# %%
df.head(3)
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
#
#      Measurements                        Affiliations  \
# 0             NaN                                 NaN
# 1  183 cm / 76 kg  Racing Club de France, Paris (FRA)
# 2  183 cm / 76 kg                    TCP, Paris (FRA)
#
#                                 Nick/petnames Title(s) Other names  \
# 0                                         NaN      NaN         NaN
# 1                                         NaN      NaN         NaN
# 2  Le Basque Bondissant (The Bounding Basque)      NaN         NaN
#
#   Nationality Original name Name order
# 0         NaN           NaN        NaN
# 1         NaN           NaN        NaN
# 2         NaN           NaN        NaN

# %%
##QUICK EXPLORATIONS
df.isna().sum()
# Out:
# Roles                 0
# Sex                   0
# Full name             0
# Used name             0
# Born               1728
# Died             111458
# NOC                   1
# athlete_id            0
# Measurements      37667
# Affiliations      49668
# Nick/petnames    136355
# Title(s)         145101
# Other names      138333
# Nationality      137241
# Original name    114761
# Name order       137656
# dtype: int64

# %% [markdown]
# **CLEANING IDEAS**
#
#
# 1.   Reducing the value in the **Role** column if the cell says *Competed in Olympic Games* it could be changed as **athlete** and the other could be changed **admin**
# 2.   The **Used name** seems to contain the name and the surname separated by dot ('.') this could be separarted.
# 3.   **Born & Died ** column also contains date of birth, city and country
# 4.   **Measurement** also contains the weight and units in it.
# 5.   **Full name, title, Original name, Name order,Affliations, Titles** could be dropped

# %%
# Dropping uncessary columns

df.drop(['Affiliations', 'Nick/petnames','Other names','Nationality','Original name',\
         'Name order','Full name', 'Roles' ], axis=1, inplace=True)
df.head(2)
# Out:
#     Sex              Used name                                         Born  \
# 0  Male  Jean-François•Blanchy  12 December 1886 in Bordeaux, Gironde (FRA)
# 1  Male         Arnaud•Boetsch       1 April 1969 in Meulan, Yvelines (FRA)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
#
#      Measurements Title(s)
# 0             NaN      NaN
# 1  183 cm / 76 kg      NaN

# %%
# let's change the values in Roles, Sex, Used name, Born and Measurements
# Let's start with Sex
df['Sex']=df['Sex'].replace('Male','M')
df['Sex']=df['Sex'].replace('Female','F')

# Result
df.head(2)
# Out:
#   Sex              Used name                                         Born  \
# 0   M  Jean-François•Blanchy  12 December 1886 in Bordeaux, Gironde (FRA)
# 1   M         Arnaud•Boetsch       1 April 1969 in Meulan, Yvelines (FRA)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
#
#      Measurements Title(s)
# 0             NaN      NaN
# 1  183 cm / 76 kg      NaN

# %%
df[df['Title(s)'].notna()& df['Used name']][['Used name', 'Title(s)']][:30]
# Out:
#                                         Used name  \
# 10                        Élie, Comte•de Lastours
# 27                             Guy, Baron•Lejeune
# 61                                  Agatha•Morton
# 104                                   Gordon•Lowe
# 531                                Dorothy•Cadman
# 572                            Geoffrey•Cornewall
# 656            Ludwig, Graf•von Salm-Hoogstraeten
# 801                                 Paola•Bologna
# 813                  Mino, Conte•Balbi Di Robecco
# 814                      Alberto, Conte•Bonacossa
# 820                            Uberto•De Morpurgo
# 1003              Christiaan, Jonkheer•van Lennep
# 1004                  Roelof, Jonkheer•van Lennep
# 2400                                 Lilí•Álvarez
# 2436                             Élisabeth•d'Ayen
# 2534              Mikhail, Count•Sumarokov-Elston
# 3366                                 Henry•Cooper
# 4644                                   Myo Thant•
# 11270       Patricia•Galvin de la Tour d'Auvergne
# 11380                           HRH Princess•Anne
# 11431  Fieps, Baroness•van Tuyll van Serooskerken
# 11434                               Ida•von Nagel
# 11447                             Lilian•Williams
# 11474          José, Marqués•Álvarez de Bohórquez
# 11504                               Norman•Arthur
# 11557           Alessandro, Conte•Bettoni Cazzago
# 11584                           Carl, Greve•Bonde
# 11652                  Ranieri, Conte•di Campello
# 11673                      Jaime, Duque•de Aveyro
# 11712               Patrick, Baron•Connolly-Carew
#
#                                                 Title(s)
# 10                                         Comte (Count)
# 27                                                 Baron
# 61                                          Lady Stewart
# 104                                  2nd Baronet of Lowe
# 531                                    Lady Wingate-Saul
# 572                6th Baronet Cornewall of Moccas Court
# 656                                         Graf (Count)
# 801                                 Baronessa (Baroness)
# 813                                        Conte (Count)
# 814                                        Conte (Count)
# 820                                       Barone (Baron)
# 1003                                            Jonkheer
# 1004                                            Jonkheer
# 2400                    Condesa (Countess) de la Valdene
# 2436   Comtesse (Countess) de Noailles et d'Ayen, Lad...
# 2534                                               Count
# 3366                                                 Sir
# 4644                                           Maung, Ko
# 11270                                           Princess
# 11380                             HRH The Princess Royal
# 11431                                           Baroness
# 11434                                      Freiin (Dame)
# 11447                                       Lady Hickman
# 11474                 Marqués (Marquis) de los Trujillos
# 11504                                                Sir
# 11557                                      Conte (Count)
# 11584                                      Greve (Count)
# 11652                                      Conte (Count)
# 11673                             Duque (Duke) de Aveyro
# 11712                                    7th Baron Carew

# %%
df['Used name'] = df['Used name'].str.replace('\u2022', '.', regex=False)

# %%
def remove_titles(name, titles):
    if pd.isna(titles):  # Handle NaN values
        return name
    for title in titles.split():  # Split title into words and remove each
        name = name.replace(title, '').strip()
    return name

df['Used name'] = df.apply(lambda row: remove_titles(row['Used name'], row['Title(s)']), axis=1)

# %%
# result
df[df['Title(s)'].notna()& df['Used name']][['Used name', 'Title(s)']][10:50]
# Out:
#                                    Used name  \
# 820                       Uberto.De Morpurgo
# 1003                 Christiaan, .van Lennep
# 1004                     Roelof, .van Lennep
# 2400                            Lilí.Álvarez
# 2436                          Élisabh.d'Ayen
# 2534              Mikhail, .Sumarokov-Elston
# 3366                            Henry.Cooper
# 4644                              Myo Thant.
# 11270  Patricia.Galvin de la Tour d'Auvergne
# 11380                                  .Anne
# 11431     Fieps, .van Tuyll van Serooskerken
# 11434                          Ida.von Nagel
# 11447                        Lilian.Williams
# 11474              José, .Álvarez  Bohórquez
# 11504                          Norman.Arthur
# 11557           Alessandro, .Bettoni Cazzago
# 11584                           Carl, .Bonde
# 11652                  Ranieri, .di Campello
# 11673                               Jaime, .
# 11712                    Patrick, .Connolly-
# 11758   Charles-Philbert, .de Couët de Lorry
# 11763                        Luis Antonio, .
# 11764         Louis-Marie.de Jonghe d'Ardoye
# 11766                  Amaury.de la Moussaye
# 11773            Ferdinand, .de Lariboisière
# 11774   Roland, .de Maille de la Tour Landry
# 11775               Henry.de Menten de Horne
# 11776       Robert, .de Montesquiou-Fézensac
# 11778                     Adrien, . Noailles
# 11779                     Jean, .de Neuflize
# 11780                                René, .
# 11784                       Karol.von Rómmel
# 11787                  Paul, .de Saint-Léger
# 11788                    Camille.de Sartiges
# 11794                        Jacques.de Waru
# 11795                     Étienne, .Van  Van
# 11817             Charles-Eugène, .de Veauce
# 11818                  Louis, .d'Havrincourt
# 11819                       Ubrto, .  Modron
# 11820                 Emanuele, .Di Pralormo
#
#                                                 Title(s)
# 820                                       Barone (Baron)
# 1003                                            Jonkheer
# 1004                                            Jonkheer
# 2400                    Condesa (Countess) de la Valdene
# 2436   Comtesse (Countess) de Noailles et d'Ayen, Lad...
# 2534                                               Count
# 3366                                                 Sir
# 4644                                           Maung, Ko
# 11270                                           Princess
# 11380                             HRH The Princess Royal
# 11431                                           Baroness
# 11434                                      Freiin (Dame)
# 11447                                       Lady Hickman
# 11474                 Marqués (Marquis) de los Trujillos
# 11504                                                Sir
# 11557                                      Conte (Count)
# 11584                                      Greve (Count)
# 11652                                      Conte (Count)
# 11673                             Duque (Duke) de Aveyro
# 11712                                    7th Baron Carew
# 11758                                              Baron
# 11763                2nd Marqués (Marquis) de Guadalmina
# 11764                                      Comte (Count)
# 11766                                 Vicomte (Viscount)
# 11773                                      Comte (Count)
# 11774                                      Comte (Count)
# 11775                                 Chevalier (Knight)
# 11776                                      Comte (Count)
# 11778   8e Duc (Duke) de Noailles, 5e Duc (Duke) de Ayen
# 11779                                              Baron
# 11780                    Comte (Count) Doynel de Quincey
# 11784                                              Baron
# 11787                                              Baron
# 11788                                      Comte (Count)
# 11794                                      Comte (Count)
# 11795                      Baron van Zuylen van Nijevelt
# 11817                                              Baron
# 11818                                      Comte (Count)
# 11819  5th Duca (Duke) Visconti di Modrone, 7th March...
# 11820                                      Conte (Count)

# %%
df['Used name'] = df['Used name'].str.replace('\u2022', '.', regex=False)

# %%
import re

def extract_first_part(name):
    """
    Extracts everything before the first dot (.) in 'Used name',
    but only if there are multiple dots present.
    """
    if name.count('.') > 1:
        return re.split(r'\.', name, maxsplit=1)[0]  # Keep only the first part
    return name

df['Used name'] = df['Used name'].apply(extract_first_part)

# %%
df[['firstName','lastName']]=df['Used name'].str.split('.', expand=True)

# %%
df.head(3)
# Out:
#   Sex              Used name  \
# 0   M  Jean-François.Blanchy
# 1   M         Arnaud.Boetsch
# 2   M           Jean.Borotra
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
#
#      Measurements Title(s)      firstName lastName
# 0             NaN      NaN  Jean-François  Blanchy
# 1  183 cm / 76 kg      NaN         Arnaud  Boetsch
# 2  183 cm / 76 kg      NaN           Jean  Borotra

# %%
# now I can drop the Used name
df.drop('Used name', axis=1, inplace=True)
cols=['firstName', 'lastName','Sex', 'Born', 'Died', 'NOC', 'athlete_id','Measurements', 'Title(s)']
df=df[cols]

# %%
df.head(2)
# Out:
#        firstName lastName Sex                                         Born  \
# 0  Jean-François  Blanchy   M  12 December 1886 in Bordeaux, Gironde (FRA)
# 1         Arnaud  Boetsch   M       1 April 1969 in Meulan, Yvelines (FRA)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
#
#      Measurements Title(s)
# 0             NaN      NaN
# 1  183 cm / 76 kg      NaN

# %%
df['Measurements']=df['Measurements'].str.replace('kg', '').str.replace('cm', '')

df[['height', 'Weight']]=df['Measurements'].str.split('/', expand=True)

df.drop('Measurements', axis=1, inplace=True)

df.head(3)
# Out:
#        firstName lastName Sex  \
# 0  Jean-François  Blanchy   M
# 1         Arnaud  Boetsch   M
# 2           Jean  Borotra   M
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
#
#   Title(s) height Weight
# 0      NaN    NaN    NaN
# 1      NaN  183      76
# 2      NaN  183      76

# %% [markdown]
# **BORN COLUMN**
# Regular expression could help help to retrieve necesary information.

# %%
df['Born'][:15]
# Out:
# 0           12 December 1886 in Bordeaux, Gironde (FRA)
# 1                1 April 1969 in Meulan, Yvelines (FRA)
# 2     13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3               11 May 1895 in Paris VIIIe, Paris (FRA)
# 4            17 April 1878 in Wandsworth, England (GBR)
# 5                13 January 1970 in Amiens, Somme (FRA)
# 6        27 November 1969 in Ris-Orangis, Essonne (FRA)
# 7         14 December 1901 in Villeurbanne, Rhône (FRA)
# 8                    4 August 1896 in Nîmes, Gard (FRA)
# 9         16 July 1868 in Farges-Allichamps, Cher (FRA)
# 10            12 August 1874 in Orgeval, Yvelines (FRA)
# 11         24 September 1882 in Paris XVIe, Paris (FRA)
# 12                                                  NaN
# 13                                                  NaN
# 14                  4 July 1969 in Vire, Calvados (FRA)
# Name: Born, dtype: object

# %%
def extract_dob_place(text):
    if pd.isna(text) or text.strip() == '':
        return pd.Series([None, None])

    # Regex to match Date and Place
    dob_match = re.search(r'\d{1,2} \w+ \d{4}', text)
    place_match = re.search(r'in (.+)', text)

    # Extracting results
    dob = dob_match.group() if dob_match else None
    place = place_match.group(1) if place_match else None

    return pd.Series([dob, place])

# %%
df[['DOB', 'Place of Birth']] = df['Born'].apply(extract_dob_place)

# %%
df['DOB']=pd.to_datetime(df['DOB'], format='mixed', errors='coerce')

# %%
df['DOB'].head(5) # result
# Out:
# 0   1886-12-12
# 1   1969-04-01
# 2   1898-08-13
# 3   1895-05-11
# 4   1878-04-17
# Name: DOB, dtype: datetime64[ns]

# %%
# extrating the country codes from Birth
df['COB'] = df['Place of Birth'].str.extract(r'\(([A-Z]{3})\)')

#removing the coiuntry codes from the Place of Birth column
df['Place of Birth'] = df['Place of Birth'].str.replace(r'\s*\([A-Z]{3}\)', '', regex=True).str.strip()

# %%
# getting rid of the Born column now
df.drop('Born', axis=1, inplace=True)

# %%
# current dataframe
df.head(3)
# Out:
#        firstName lastName Sex  \
# 0  Jean-François  Blanchy   M
# 1         Arnaud  Boetsch   M
# 2           Jean  Borotra   M
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
#
#   Title(s) height Weight        DOB                  Place of Birth  COB
# 0      NaN    NaN    NaN 1886-12-12               Bordeaux, Gironde  FRA
# 1      NaN  183      76  1969-04-01                Meulan, Yvelines  FRA
# 2      NaN  183      76  1898-08-13  Biarritz, Pyrénées-Atlantiques  FRA

# %% [markdown]
# Let's sort out the  **Died** column

# %%
df[['Death_date', 'Death_place']] = df['Died'].apply(extract_dob_place)

# %%
df[['Death_date', 'Death_place']].head(10)
# Out:
#        Death_date                                    Death_place
# 0  2 October 1960  Saint-Jean-de-Luz, Pyrénées-Atlantiques (FRA)
# 1            None                                           None
# 2    17 July 1994            Arbonne, Pyrénées-Atlantiques (FRA)
# 3   20 March 1978                           Monaco, Monaco (MON)
# 4    25 July 1930                        Paris VIIe, Paris (FRA)
# 5            None                                           None
# 6            None                                           None
# 7    2 April 1987          Saint-Germain-en-Laye, Yvelines (FRA)
# 8   1 August 1986                              Nîmes, Gard (FRA)
# 9            None                                           None

# %%
#changing the date format
df['Death_date']=pd.to_datetime(df['Death_date'], format='mixed', errors='coerce')


# extrating the country codes from Death place
df['COD'] = df['Death_place'].str.extract(r'\(([A-Z]{3})\)')

#removing the coiuntry codes from the Place of death
df['Death_place'] = df['Death_place'].str.replace(r'\s*\([A-Z]{3}\)', '', regex=True).str.strip()

# %%
# dropping the Died column
df.drop('Died', axis=1, inplace=True)

# %%
df.head(2)
# Out:
#        firstName lastName Sex     NOC  athlete_id Title(s) height Weight  \
# 0  Jean-François  Blanchy   M  France           1      NaN    NaN    NaN
# 1         Arnaud  Boetsch   M  France           2      NaN  183      76
#
#          DOB     Place of Birth  COB Death_date  \
# 0 1886-12-12  Bordeaux, Gironde  FRA 1960-10-02
# 1 1969-04-01   Meulan, Yvelines  FRA        NaT
#
#                                Death_place  COD
# 0  Saint-Jean-de-Luz, Pyrénées-Atlantiques  FRA
# 1                                     None  NaN

# %%
# renaming the columns
df.rename(columns={'firstName': 'Firstname',
                   'lastName': 'Lastname',
                   'NOC': 'NOC',
                   'Place of Birth': 'PoB',
                   'Death_date': 'DoD',
                   'Death_place': 'PoD',
                   'COD': 'CoD'}, inplace=True)

#reordering the columns
cols=['athlete_id','Firstname','Firstname','Title(s)','Sex','NOC','DOB','PoB','COB','height','Weight',\
      'DoD','PoD','CoD']
df=df[cols]

# %%
df.head()
# Out:
#    athlete_id      Firstname      Firstname Title(s) Sex     NOC        DOB  \
# 0           1  Jean-François  Jean-François      NaN   M  France 1886-12-12
# 1           2         Arnaud         Arnaud      NaN   M  France 1969-04-01
# 2           3           Jean           Jean      NaN   M  France 1898-08-13
# 3           4        Jacques        Jacques      NaN   M  France 1895-05-11
# 4           5         Albert         Albert      NaN   M  France 1878-04-17
#
#                               PoB  COB height Weight        DoD  \
# 0               Bordeaux, Gironde  FRA    NaN    NaN 1960-10-02
# 1                Meulan, Yvelines  FRA  183      76         NaT
# 2  Biarritz, Pyrénées-Atlantiques  FRA  183      76  1994-07-17
# 3              Paris VIIIe, Paris  FRA  168      64  1978-03-20
# 4             Wandsworth, England  GBR    NaN    NaN 1930-07-25
#
#                                        PoD  CoD
# 0  Saint-Jean-de-Luz, Pyrénées-Atlantiques  FRA
# 1                                     None  NaN
# 2            Arbonne, Pyrénées-Atlantiques  FRA
# 3                           Monaco, Monaco  MON
# 4                        Paris VIIe, Paris  FRA

# %% [markdown]
# 1. **Retention of the "Title(s)" Column:**
#    The "Title(s)" column has been preserved in the dataset as it provides valuable information for identifying athletes with aristocratic or honorary distinctions. This can be useful for recognizing individuals with significant social status, which may be relevant for specific analyses or reporting.
#
# 2. **Enhancement of the "NOC" Column:**
#    Further improvements can be made to the "NOC" column to standardize it as a three-letter country code format, in line with international sports conventions. This transformation would enhance data consistency and simplify filtering, sorting, and analysis by national representation.
